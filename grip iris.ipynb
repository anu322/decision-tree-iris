# %% [markdown]
# ## Prediction using Decision Tree Algorithm -- Anuradha Tandon
#
# - For the given ‘Iris’ dataset, create the Decision Tree classifier and visualize it
# graphically.
# - The purpose is if we feed any new data to this classifier, it would be able to
# predict the right class accordingly.
# - Dataset : https://bit.ly/3kXTdox

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/Anu/Desktop/iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.drop("Id",axis=1,inplace=True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df['Species'].describe()
# Out:
# count                 150
# unique                  3
# top       Iris-versicolor
# freq                   50
# Name: Species, dtype: object

# %% [markdown]
# ## Correlation Table

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn')

# %%
sns.countplot(x='Species',data=df)

# %% [markdown]
# ## Numerical Features

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,sharey=False,figsize=(10,6))
ax=sns.distplot(df['SepalLengthCm'],ax=ax1)
ax=df['SepalLengthCm'].plot.box(ax=ax2)
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,sharey=False,figsize=(10,6))
ax=sns.distplot(df['SepalWidthCm'],ax=ax1)
ax=df['SepalWidthCm'].plot.box(ax=ax2)
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,sharey=False,figsize=(10,6))
ax=sns.distplot(df['PetalLengthCm'],ax=ax1)
ax=df['PetalLengthCm'].plot.box(ax=ax2)
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,sharey=False,figsize=(10,6))
ax=sns.distplot(df['PetalWidthCm'],ax=ax1)
ax=df['PetalWidthCm'].plot.box(ax=ax2)
plt.show()

# %%
df['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris0=df[df['Species']=='Iris-virginica']
iris1=df[df['Species']=='Iris-setosa']
iris2=df[df['Species']=='Iris-versicolor']

# %%
iris0.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 100            6.3           3.3            6.0           2.5  Iris-virginica
# 101            5.8           2.7            5.1           1.9  Iris-virginica
# 102            7.1           3.0            5.9           2.1  Iris-virginica
# 103            6.3           2.9            5.6           1.8  Iris-virginica
# 104            6.5           3.0            5.8           2.2  Iris-virginica

# %%
plt.scatter(x="SepalLengthCm",y='SepalWidthCm',c='green',data=iris0)
plt.scatter(x="SepalLengthCm",y="SepalWidthCm",c='red',data=iris1)
plt.scatter(x="SepalLengthCm",y="SepalWidthCm",c='black',data=iris2)
plt.show()

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
plt.scatter(x="SepalLengthCm",y="PetalLengthCm",c='green',data=iris0)
plt.scatter(x="SepalLengthCm",y="PetalLengthCm",c='red',data=iris1)
plt.scatter(x="SepalLengthCm",y="PetalLengthCm",c='black',data=iris2)
plt.show()

# %%
plt.scatter(x="SepalLengthCm",y="PetalWidthCm",c='green',data=iris0)
plt.scatter(x="SepalLengthCm",y="PetalWidthCm",c='red',data=iris1)
plt.scatter(x="SepalLengthCm",y="PetalWidthCm",c='black',data=iris2)
plt.show()

# %%
y=df['Species']

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
x=df.drop('Species',axis=1)

# %%
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
clf=DecisionTreeClassifier(criterion='gini',splitter='best',max_depth=2)
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
clf.score(x_test,y_test)
# Out:
# 0.9736842105263158

# %%
prediction=clf.predict(x_test)

# %%
from sklearn import metrics

# %%
print("Accuracy :",clf.score(x_test, y_test)*100,"%")
# Out:
# Accuracy : 97.36842105263158 %

# %%
print(metrics.accuracy_score(y_test, prediction))

print(metrics.classification_report(y_test, prediction))
# Out:
# 0.9736842105263158
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       1.00      0.91      0.95        11
#  Iris-virginica       0.92      1.00      0.96        12
#
#        accuracy                           0.97        38
#       macro avg       0.97      0.97      0.97        38
#    weighted avg       0.98      0.97      0.97        38

# %%
cm=metrics.confusion_matrix(y_test, prediction)
sns.heatmap(cm,annot=True,cmap='RdYlGn')

# %%
plot_tree(clf)
# Out:
# [Text(133.92000000000002, 181.2, 'X[2] <= 2.45\nentropy = 0.666\nsamples = 112\nvalue = [35, 39, 38]'),
#  Text(66.96000000000001, 108.72, 'entropy = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(200.88000000000002, 108.72, 'X[2] <= 4.75\nentropy = 0.5\nsamples = 77\nvalue = [0, 39, 38]'),
#  Text(133.92000000000002, 36.23999999999998, 'entropy = 0.056\nsamples = 35\nvalue = [0, 34, 1]'),
#  Text(267.84000000000003, 36.23999999999998, 'entropy = 0.21\nsamples = 42\nvalue = [0, 5, 37]')]

# %%
plt.plot(prediction)
plt.show()

# %%
plt.plot(y_test.values)
plt.show()

# %%
plt.plot(prediction)
plt.plot(y_test.values)
plt.show()
